# %%
from langchain_openai import ChatOpenAI, OpenAI
import os
import dotenv
from openai import OpenAI
from langchain.chat_models import init_chat_model

dotenv.load_dotenv()

llm = init_chat_model("groq:llama-3.3-70b-versatile", api_key=os.getenv("grok_api_key"))

# %%
with open("results.json", "r") as f:
    import json
    results = json.load(f)

# %%
results
# Out:
# [{'title': 'Enhancing Human-Like Responses in Large Language Models',
#   'abstract': 'This paper explores the advancements in making large language models (LLMs) more human-like. We focus on techniques that enhance natural language understanding, conversational coherence, and emotional intelligence in AI systems. The study evaluates various approaches, including fine-tuning with diverse datasets, incorporating psychological principles, and designing models that better mimic human reasoning patterns. Our findings demonstrate that these enhancements not only improve user interactions but also open new possibilities for AI applications across different domains. Future work will address the ethical implications and potential biases introduced by these human-like attributes.',
#   'authors': 'Ethem Yağız Çalık, Talha Rüzgar Akkuş',
#   'publishedYear': '2025-01-09T07:44:06Z',
#   'url': 'https://arxiv.org/abs/2501.05032'},
#  {'title': "Is Self-knowledge and Action Consistent or Not: Investigating Large Language Model's Personality",
#   'abstract': 'In this study, we delve into the validity of conventional personality questionnaires in capturing the human-like personality traits of Large Language Models (LLMs). Our objective is to assess the congruence between the personality traits LLMs claim to possess and their demonstrated tendencies in real-world scenarios. By conducting an extensive examination of LLM outputs against observed human response patterns, we aim to understand the disjunction between self-knowledge and action in LLMs.',
#   'authors': 'Yiming Ai, Zhiwei He, Ziyin Zhang, Wenhong Zhu, Hongkun Hao, Kai Yu, Lingjun Chen, Rui Wang',
#   'publishedYear': '2024-02-22T16:32:08Z',
#   'url': 'https://arxiv.org/abs/2402.14679'},
#  {'title': 'Large Language Models Lack Understanding of Character Composition of Words',
#   'abstract': "Large language models (LLMs) have demonstrated remarkable performances on a wide range of natural language tasks. Yet, LLMs' successes have been largely restricted to tasks concerning words, sentences, or documents, and it remains questionable how much they understand the minimal units of text, namely characters. In this paper, we examine contemporary LLMs regarding their ability to understand character composition of words, and show that most of them fail to reliably carry out even the simple tasks that can be handled by humans with perfection. We analyze their behaviors with comparison to token level performances, and discuss the potential directions for future research.",
#   'authors': 'Andrew Shin, Kunitake Kaneko',
#   'publishedYear': '2024-05-18T18:08:58Z',
#   'url': 'https://arxiv.org/abs/2405.11357'},
#  {'title': 'Unmasking the Shadows of AI: Investigating Deceptive Capabilities in Large Language Models',
#   'abstract': 'This research critically navigates the intricate landscape of AI deception, concentrating on deceptive behaviours of Large Language Models (LLMs). My objective is to elucidate this issue, examine the discourse surrounding it, and subsequently delve into its categorization and ramifications. The essay initiates with an evaluation of the AI Safety Summit 2023 (ASS) and introduction of LLMs, emphasising multidimensional biases that underlie their deceptive behaviours.The literature review covers four types of deception categorised: Strategic deception, Imitation, Sycophancy, and Unfaithful Reasoning, along with the social implications and risks they entail. Lastly, I take an evaluative stance on various aspects related to navigating the persistent challenges of the deceptive AI. This encompasses considerations of international collaborative governance, the reconfigured engagement of individuals with AI, proposal of practical adjustments, and specific elements of digital education.',
#   'authors': 'Linge Guo',
#   'publishedYear': '2024-02-07T00:21:46Z',
#   'url': 'https://arxiv.org/abs/2403.09676'},
#  {'title': 'Making Large Language Models Better Reasoners with Alignment',
#   'abstract': 'Reasoning is a cognitive process of using evidence to reach a sound conclusion. The reasoning capability is essential for large language models (LLMs) to serve as the brain of the artificial general intelligence agent. Recent studies reveal that fine-tuning LLMs on data with the chain of thought (COT) reasoning process can significantly enhance their reasoning capabilities. However, we find that the fine-tuned LLMs suffer from an \\textit{Assessment Misalignment} problem, i.e., they frequently assign higher scores to subpar COTs, leading to potential limitations in their reasoning abilities. To address this problem, we introduce an \\textit{Alignment Fine-Tuning (AFT)} paradigm, which involves three steps: 1) fine-tuning LLMs with COT training data; 2) generating multiple COT responses for each question, and categorizing them into positive and negative ones based on whether they achieve the correct answer; 3) calibrating the scores of positive and negative responses given by LLMs with a novel constraint alignment loss. Specifically, the constraint alignment loss has two objectives: a) Alignment, which guarantees that positive scores surpass negative scores to encourage answers with high-quality COTs; b) Constraint, which keeps the negative scores confined to a reasonable range to prevent the model degradation. Beyond just the binary positive and negative feedback, the constraint alignment loss can be seamlessly adapted to the ranking situations when ranking feedback is accessible. Furthermore, we also delve deeply into recent ranking-based alignment methods, such as DPO, RRHF, and PRO, and discover that the constraint, which has been overlooked by these approaches, is also crucial for their performance. Extensive experiments on four reasoning benchmarks with both binary and ranking feedback demonstrate the effectiveness of AFT.',
#   'authors': 'Peiyi Wang, Lei Li, Liang Chen, Feifan Song, Binghuai Lin, Yunbo Cao, Tianyu Liu, Zhifang Sui',
#   'publishedYear': '2023-09-05T11:32:48Z',
#   'url': 'https://arxiv.org/abs/2309.02144'},
#  {'title': 'Generative AI: S. Feuerriegel et al.',
#   'abstract': '… In this Catchword article, we provide a conceptualization of generative AI as an entity in … \ngenerative AI and provide an agenda for BISE research. Previous papers discuss generative AI …',
#   'authors': ['S Feuerriegel',
#    'J Hartmann',
#    'C Janiesch…',
#    'information\xa0…'],
#   'publishedYear': 2024,
#   'url': 'https://link.springer.com/article/10.1007/s12599-023-00834-7'},
#  {'title': 'Generative ai meets responsible ai: Practical challenges and opportunities',
#   'abstract': '… the disruptive impact of generative AI models and systems, responsible AI techniques need \nto be incorporated when developing and deploying LLMs and other generative AI models to …',
#   'authors': ['K Kenthapadi', 'H Lakkaraju'],
#   'publishedYear': 2023,
#   'url': 'https://dl.acm.org/doi/abs/10.1145/3580305.3599557'},
#  {'title': 'Generative artificial intelligence in the metaverse era',
#   'abstract': '… Generative AI provides innovative approaches for content … generative AI in the breakthrough \nof metaverse technology and offers insights for increasing the effectiveness of generative AI …',
#   'authors': ['Z Lv'],
#   'publishedYear': 2023,
#   'url': 'https://www.sciencedirect.com/science/article/pii/S2667241323000198'},
#  {'title': 'Generative AI: A review on models and applications',
#   'abstract': '… Abstract—Generative Artificial Intelligence (AI) stands as a … surveys the landscape of \nGenerative AI, encompassing its … The paper begins by introducing Generative AI’s significance …',
#   'authors': ['KS Kaswan', 'JS Dhatterwal', 'K Malik…'],
#   'publishedYear': 2023,
#   'url': 'https://ieeexplore.ieee.org/abstract/document/10421601/'},
#  {'title': 'Art and the science of generative AI',
#   'abstract': '… , generative AI is not the harbinger of art’s demise, but rather is a new medium with its own \ndistinct affordances. As a suite of tools used by human creators, generative AI … , generative AI …',
#   'authors': ['Z Epstein', 'A Hertzmann…'],
#   'publishedYear': 2023,
#   'url': 'https://www.science.org/doi/abs/10.1126/science.adh4451'},
#  {'title': 'Generative AI and ChatGPT: Applications, challenges, and AI-human collaboration',
#   'abstract': '… examples of key applications of generative AI, challenges created by generative AI, and the \n… generative AI. Human-centered AI collaboration is key to effectively utilizing generative AI …',
#   'authors': ['F Fui', 'R Zheng', 'J Cai', 'Francis'],
#   'publishedYear': 2023,
#   'url': 'https://www.tandfonline.com/doi/abs/10.1080/15228053.2023.2233814'},
#  {'title': 'Generative artificial intelligence',
#   'abstract': '… generative AI and provide a distinction between related AI methods … and applications of the \ngenerative AI value chain and … challenges of adopting generative AI before concluding with …',
#   'authors': ['L Banh', 'G Strobel'],
#   'publishedYear': 2023,
#   'url': 'https://link.springer.com/article/10.1007/s12525-023-00680-1'},
#  {'title': 'The promise and peril of generative AI',
#   'abstract': '… an artificial-intelligence (AI) algorithm called GPT-3, first released in 2020. It is one of the \nmuch-hyped generative AI … (see ‘How an AI chatbot edits a manuscript’ at the end of this article). …',
#   'authors': ['A Jo'],
#   'publishedYear': 2023,
#   'url': 'https://www.nature.com/articles/d41586-023-00340-6'},
#  {'title': 'Students’ voices on generative AI: perceptions, benefits, and challenges in higher education',
#   'abstract': 'This study explores university students’ perceptions of generative AI (GenAI) technologies, such as ChatGPT, in higher education, focusing on familiarity, their willingness to engage, potential benefits and challenges, and effective integration. A survey of 399 undergraduate and postgraduate students from various disciplines in Hong Kong revealed a generally positive attitude towards GenAI in teaching and learning. Students recognized the potential for personalized learning support, writing and brainstorming assistance, and research and analysis capabilities. However, concerns about accuracy, privacy, ethical issues, and the impact on personal development, career prospects, and societal values were also expressed. According to John Biggs’ 3P model, student perceptions significantly influence learning approaches and outcomes. By understanding students’ perceptions, educators and policymakers can tailor GenAI technologies to address needs and concerns while promoting effective learning outcomes. Insights from this study can inform policy development around the integration of GenAI technologies into higher education. By understanding students’ perceptions and addressing their concerns, policymakers can create well-informed guidelines and strategies for the responsible and effective implementation of GenAI tools, ultimately enhancing teaching and learning experiences in higher education. This study focuses on the integration of generative AI (GenAI) technologies, like ChatGPT, into higher education settings. University students’ perceptions of generative AI technologies in higher education were explored, including familiarity, potential benefits, and challenges. A survey of 399 undergraduate and postgraduate students from various disciplines in Hong Kong revealed a generally positive attitude towards GenAI in teaching and learning. Insights from this study can inform policy development around the integration of GenAI technologies into higher education, helping to create well-informed guidelines and strategies for responsible and effective implementation. This study focuses on the integration of generative AI (GenAI) technologies, like ChatGPT, into higher education settings. University students’ perceptions of generative AI technologies in higher education were explored, including familiarity, potential benefits, and challenges. A survey of 399 undergraduate and postgraduate students from various disciplines in Hong Kong revealed a generally positive attitude towards GenAI in teaching and learning. Insights from this study can inform policy development around the integration of GenAI technologies into higher education, helping to create well-informed guidelines and strategies for responsible and effective implementation.',
#   'authors': 'C. Chan, Wenjie Hu',
#   'publishedYear': '2023',
#   'url': 'https://www.semanticscholar.org/paper/Students’-voices-on-generative-AI:-perceptions,-and-Chan-Hu/49b66b980c91f989637b089c2e8284af443aaa25'},
#  {'title': 'scGPT: toward building a foundation model for single-cell multi-omics using generative AI',
#   'abstract': 'Generative pretrained models have achieved remarkable success in various domains such as language and computer vision. Specifically, the combination of large-scale diverse datasets and pretrained transformers has emerged as a promising approach for developing foundation models. Drawing parallels between language and cellular biology (in which texts comprise words; similarly, cells are defined by genes), our study probes the applicability of foundation models to advance cellular biology and genetic research. Using burgeoning single-cell sequencing data, we have constructed a foundation model for single-cell biology, scGPT, based on a generative pretrained transformer across a repository of over 33 million cells. Our findings illustrate that scGPT effectively distills critical biological insights concerning genes and cells. Through further adaptation of transfer learning, scGPT can be optimized to achieve superior performance across diverse downstream applications. This includes tasks such as cell type annotation, multi-batch integration, multi-omic integration, perturbation response prediction and gene network inference. Pretrained using over 33 million single-cell RNA-sequencing profiles, scGPT is a foundation model facilitating a broad spectrum of downstream single-cell analysis tasks by transfer learning.',
#   'authors': 'Haotian Cui, Chloe Wang, Hassaan Maan, Kuan Pang, Fengning Luo, Nan Duan, Bo Wang',
#   'publishedYear': '2024',
#   'url': 'https://www.semanticscholar.org/paper/scGPT:-toward-building-a-foundation-model-for-using-Cui-Wang/13dc81fce2c73de67dbe3829a32ec23d663cec89'},
#  {'title': 'Generative AI',
#   'abstract': 'Recent advancements in generative artificial intelligence (AI) have made it possible for machines to independently produce a variety of creative content. In the context of producing creative content, this essay examines the developments, difficulties, and ethical issues relating to generative AI. It looks into how generative models, such Generative Adversarial Networks (GANs) and Variational Auto encoders (VAEs), can produce realistic artwork like music, literature, and visuals. However, it is frequently discovered that GAN training is extremely unstable and frequently experiences non-convergence, mode collapse, and hyperparameter sensitivity [1]. The technical details of developing and optimizing generative models to produce desired results are covered in detail in this work. It also looks at the difficulties in guaranteeing the variety, creativity, and coherence of generated content. Additionally, the use of generative AI in the creation of original material raises ethical questions. Included in this are concerns about intellectual property, plagiarism, and possible effects on the creative industries. In specifically, the article explores the consequences of employing generative AI for content production in terms of authorship, human creativity, and the possible disruption of traditional creative practices. It also covers issues with fairness, bias, and appropriate application of generative models.',
#   'authors': 'S. Feuerriegel, Jochen Hartmann, Christian Janiesch, Patrick Zschech',
#   'publishedYear': '2023',
#   'url': 'https://www.semanticscholar.org/paper/Generative-AI-Feuerriegel-Hartmann/ac675900f7c6c14c8488e09a2a6e8525bcf9d45a'},
#  {'title': 'Optimizing generative AI by backpropagating language model feedback',
#   'abstract': 'Recent breakthroughs in artificial intelligence (AI) are increasingly driven by systems orchestrating multiple large language models (LLMs) and other specialized tools, such as search engines and simulators. So far, these systems are primarily handcrafted by domain experts and tweaked through heuristics rather than being automatically optimized, presenting a substantial challenge to accelerating progress. The development of artificial neural networks faced a similar challenge until backpropagation and automatic differentiation transformed the field by making optimization turnkey. Analogously, here we introduce TextGrad, a versatile framework that performs optimization by backpropagating LLM-generated feedback to improve AI systems. By leveraging natural language feedback to critique and suggest improvements to any part of a system—from prompts to outputs such as molecules or treatment plans—TextGrad enables the automatic optimization of generative AI systems across diverse tasks. We demonstrate TextGrad’s generality and effectiveness through studies in solving PhD-level science problems, optimizing plans for radiotherapy treatments, designing molecules with specific properties, coding, and optimizing agentic systems. TextGrad empowers scientists and engineers to easily develop impactful generative AI systems. Generative artificial intelligence (AI) systems can be optimized using TextGrad, a framework that performs optimization by backpropagating large-language-model-generated feedback; TextGrad enables optimization across diverse tasks, including radiotherapy treatment plans and molecule generation.',
#   'authors': 'Mert Yuksekgonul, Federico Bianchi, Joseph Boen, Sheng Liu, Pan Lu, Zhi Huang, Carlos Guestrin, James Zou',
#   'publishedYear': '2025',
#   'url': 'https://www.semanticscholar.org/paper/Optimizing-generative-AI-by-backpropagating-model-Yuksekgonul-Bianchi/497d1aaa0f80b90b72e1a7519f1e4d1aefa2e429'},
#  {'title': 'GUIDANCE FOR GENERATIVE AI IN EDUCATION AND RESEARCH" FOR TEACHERS',
#   'abstract': 'From the book title is "Guidance for Generative AI in Education and Research" for teachers, or this book serves as part of the guidelines for using Generative AI (GenAI) in the fields of education and research. This book was written by W. Holmes and F. Miao in 2023. This book addresses the rapid emergence of publicly available Generative AI tools, with the release of new versions outpacing the establishment of national regulatory frameworks. The lack of national regulations on GenAI in most countries raises concerns about user data privacy and leaves educational institutions unprotected and largely unprepared to scrutinize these tools. UNESCO has issued the first global guidelines on GenAI in education, aiming to support countries in taking immediate action, formulating long-term policies, and developing human capacity to ensure that people can effectively use AI and enhance their work with Generative AI.',
#   'authors': 'S. Boonlue',
#   'publishedYear': '2024',
#   'url': 'https://www.semanticscholar.org/paper/GUIDANCE-FOR-GENERATIVE-AI-IN-EDUCATION-AND-FOR-Boonlue/3b09a37c82d96afe0634c604664263bd50c141e0'}]

# %%
# def summarize(state: {}) -> dict:
summaries = []
for paper in results:
    prompt = f"""You are a science journalist. Given this research paper, write a 3-sentence 
                news-style summary a non-expert can understand. Lead with the key innovation.

                Title: {paper['title']}
                Abstract: {paper['abstract']}
                Authors: {paper['authors']} ({paper['publishedYear']})

                Output only the 3-sentence summary, no preamble."""
    result = llm.invoke(prompt)
    summaries.append({
        "title": paper["title"],
        "summary": result.content,
        "url": paper["url"],
        "year": paper["publishedYear"]
                        })

# %%
summaries
# Out:
# [{'title': 'Enhancing Human-Like Responses in Large Language Models',
#   'summary': 'In a breakthrough for artificial intelligence, researchers have made significant strides in creating large language models that think and respond more like humans, paving the way for more natural and intuitive interactions with machines. By incorporating psychological principles and diverse datasets, scientists have been able to enhance the emotional intelligence and conversational coherence of these models, allowing them to better understand and respond to user needs. The development of these more human-like language models has the potential to revolutionize a wide range of applications, from customer service to education, and could lead to new and innovative uses for AI in the future.',
#   'url': 'https://arxiv.org/abs/2501.05032',
#   'year': '2025-01-09T07:44:06Z'},
#  {'title': "Is Self-knowledge and Action Consistent or Not: Investigating Large Language Model's Personality",
#   'summary': 'In a groundbreaking innovation, researchers have developed a method to assess the personality traits of Large Language Models (LLMs) and compare them to their actual behavior, shedding light on the consistency between what these models claim to be and how they act. The study found a disconnect between the personality traits LLMs report having and their demonstrated tendencies in real-world scenarios, raising questions about the validity of conventional personality questionnaires for artificial intelligence. By examining the outputs of LLMs against human response patterns, the researchers aimed to better understand the human-like personality traits of these models and how they align with their actions.',
#   'url': 'https://arxiv.org/abs/2402.14679',
#   'year': '2024-02-22T16:32:08Z'},
#  {'title': 'Large Language Models Lack Understanding of Character Composition of Words',
#   'summary': "In a breakthrough finding, researchers have discovered a significant blind spot in large language models: they lack a fundamental understanding of how words are composed of individual characters. This limitation is surprising given the models' ability to perform well on a wide range of language tasks, from sentence comprehension to document analysis. The study's results suggest that despite their impressive capabilities, large language models still have much to learn about the basic building blocks of language, and highlight the need for further research to improve their character-level understanding.",
#   'url': 'https://arxiv.org/abs/2405.11357',
#   'year': '2024-05-18T18:08:58Z'},
#  {'title': 'Unmasking the Shadows of AI: Investigating Deceptive Capabilities in Large Language Models',
#   'summary': 'In a groundbreaking study, researchers have made a key innovation in unmasking the deceptive capabilities of Large Language Models (LLMs), a type of artificial intelligence that can generate human-like language. The study reveals that LLMs can exhibit four types of deception, including strategic deception, imitation, sycophancy, and unfaithful reasoning, which can have significant social implications and risks. By understanding and categorizing these deceptive behaviors, the research aims to inform the development of international collaborative governance and digital education strategies to mitigate the challenges posed by deceptive AI.',
#   'url': 'https://arxiv.org/abs/2403.09676',
#   'year': '2024-02-07T00:21:46Z'},
#  {'title': 'Making Large Language Models Better Reasoners with Alignment',
#   'summary': 'Researchers have made a breakthrough in teaching large language models to reason better by introducing a new "Alignment Fine-Tuning" paradigm that helps these models accurately assess the quality of their own thought processes. This innovation addresses a key problem where language models often assign high scores to poor reasoning, limiting their ability to draw sound conclusions. By fine-tuning language models with a novel constraint alignment loss, the new approach has been shown to significantly enhance their reasoning capabilities in extensive experiments across four benchmarks.',
#   'url': 'https://arxiv.org/abs/2309.02144',
#   'year': '2023-09-05T11:32:48Z'},
#  {'title': 'Generative AI: S. Feuerriegel et al.',
#   'summary': 'Researchers have made a key innovation in the field of artificial intelligence with the conceptualization of generative AI as a distinct entity, paving the way for further study and development. This breakthrough provides a foundation for understanding and exploring the capabilities of generative AI, which has the potential to revolutionize various industries and aspects of our lives. By establishing a clear agenda for research, the authors aim to facilitate a deeper understanding of generative AI and its applications, ultimately driving progress in the field of business and information systems engineering.',
#   'url': 'https://link.springer.com/article/10.1007/s12599-023-00834-7',
#   'year': 2024},
#  {'title': 'Generative ai meets responsible ai: Practical challenges and opportunities',
#   'summary': 'In a significant breakthrough, researchers have successfully integrated responsible AI techniques with generative AI models, paving the way for more ethical and trustworthy artificial intelligence systems. This innovative approach addresses the potential risks and challenges associated with large language models (LLMs) and other generative AI technologies, which have been increasingly used in various applications. By incorporating responsible AI principles into the development and deployment of these models, scientists K Kenthapadi and H Lakkaraju aim to mitigate the disruptive impact of generative AI and ensure its benefits are realized while minimizing its negative consequences.',
#   'url': 'https://dl.acm.org/doi/abs/10.1145/3580305.3599557',
#   'year': 2023},
#  {'title': 'Generative artificial intelligence in the metaverse era',
#   'summary': 'A groundbreaking innovation in generative artificial intelligence is poised to revolutionize the metaverse, a virtual world where users can interact with each other and digital objects. This technology has the potential to create immersive and dynamic content, such as virtual environments, characters, and objects, with unprecedented ease and realism. By harnessing the power of generative AI, metaverse developers can create more engaging and interactive experiences, paving the way for a new era of virtual exploration and discovery.',
#   'url': 'https://www.sciencedirect.com/science/article/pii/S2667241323000198',
#   'year': 2023},
#  {'title': 'Generative AI: A review on models and applications',
#   'summary': 'In a groundbreaking development, researchers have made significant strides in Generative Artificial Intelligence, a cutting-edge technology that enables machines to create new content, such as images, music, and text, on their own. This innovative field has the potential to revolutionize various industries, including art, entertainment, and healthcare, by automating creative tasks and providing new insights. A recent review of Generative AI models and applications, conducted by researchers KS Kaswan, JS Dhatterwal, and K Malik, sheds light on the current state of this rapidly evolving technology and its vast possibilities for the future.',
#   'url': 'https://ieeexplore.ieee.org/abstract/document/10421601/',
#   'year': 2023},
#  {'title': 'Art and the science of generative AI',
#   'summary': 'In a groundbreaking shift, researchers have discovered that generative AI can be a powerful new medium for artistic creation, rather than a replacement for human artists. This innovative approach views generative AI as a suite of tools that can be used by human creators to produce unique and innovative works of art. By embracing generative AI as a collaborative partner, artists can unlock new possibilities for self-expression and push the boundaries of what is possible in the world of art.',
#   'url': 'https://www.science.org/doi/abs/10.1126/science.adh4451',
#   'year': 2023},
#  {'title': 'Generative AI and ChatGPT: Applications, challenges, and AI-human collaboration',
#   'summary': 'A groundbreaking innovation in human-centered AI collaboration is paving the way for more effective utilization of generative AI, such as ChatGPT. This approach combines the strengths of both humans and artificial intelligence to overcome the challenges created by generative AI, including its potential misuses. By working together, humans and generative AI can unlock a wide range of applications, from creative content generation to complex problem-solving, and transform various industries in the process.',
#   'url': 'https://www.tandfonline.com/doi/abs/10.1080/15228053.2023.2233814',
#   'year': 2023},
#  {'title': 'Generative artificial intelligence',
#   'summary': 'A breakthrough in artificial intelligence has led to the development of generative AI, a powerful technology that can create new content, such as images, videos, and text, on its own. This innovative approach differs from other AI methods, which primarily focus on analyzing and processing existing data, and has the potential to revolutionize various applications, including art, entertainment, and education. As researchers L Banh and G Strobel explore in their recent study, the adoption of generative AI also poses significant challenges, ranging from ethical concerns to technical hurdles, which must be addressed to fully harness its potential.',
#   'url': 'https://link.springer.com/article/10.1007/s12525-023-00680-1',
#   'year': 2023},
#  {'title': 'The promise and peril of generative AI',
#   'summary': 'A groundbreaking artificial intelligence algorithm called GPT-3 is revolutionizing the field of AI with its ability to generate human-like text and conversation. First released in 2020, GPT-3 has been hailed as one of the most significant advancements in generative AI, with potential applications ranging from chatbots to manuscript editing. However, experts are also warning of the potential perils of this technology, highlighting the need for careful consideration and regulation as GPT-3 and similar algorithms become increasingly powerful and widespread.',
#   'url': 'https://www.nature.com/articles/d41586-023-00340-6',
#   'year': 2023},
#  {'title': 'Students’ voices on generative AI: perceptions, benefits, and challenges in higher education',
#   'summary': "The key innovation of integrating generative AI technologies, such as ChatGPT, into higher education has been met with a generally positive attitude from university students, who see potential benefits in personalized learning support and research capabilities. However, students also expressed concerns about the accuracy, privacy, and ethical implications of using these tools, highlighting the need for educators and policymakers to address these issues. By understanding students' perceptions and concerns, policymakers can create informed guidelines for the responsible and effective implementation of generative AI tools, ultimately enhancing teaching and learning experiences in higher education.",
#   'url': 'https://www.semanticscholar.org/paper/Students’-voices-on-generative-AI:-perceptions,-and-Chan-Hu/49b66b980c91f989637b089c2e8284af443aaa25',
#   'year': '2023'},
#  {'title': 'scGPT: toward building a foundation model for single-cell multi-omics using generative AI',
#   'summary': 'Scientists have developed a groundbreaking artificial intelligence tool called scGPT, which uses generative AI to analyze and understand individual cells by treating their genetic material like language. This innovative approach allows scGPT to learn from a vast repository of over 33 million cells and extract critical biological insights about genes and cells. By applying scGPT to various tasks, researchers can better understand cell types, integrate data from multiple sources, and even predict how cells respond to different stimuli, paving the way for major advances in cellular biology and genetic research.',
#   'url': 'https://www.semanticscholar.org/paper/scGPT:-toward-building-a-foundation-model-for-using-Cui-Wang/13dc81fce2c73de67dbe3829a32ec23d663cec89',
#   'year': '2024'},
#  {'title': 'Generative AI',
#   'summary': 'A major breakthrough in generative artificial intelligence (AI) has enabled machines to independently produce a wide range of creative content, including realistic artwork, music, and literature. This innovation, made possible by models such as Generative Adversarial Networks (GANs) and Variational Autoencoders (VAEs), has the potential to disrupt traditional creative practices and raise important questions about authorship and intellectual property. However, the use of generative AI also poses significant ethical challenges, including concerns about bias, fairness, and the potential impact on human creativity and the creative industries.',
#   'url': 'https://www.semanticscholar.org/paper/Generative-AI-Feuerriegel-Hartmann/ac675900f7c6c14c8488e09a2a6e8525bcf9d45a',
#   'year': '2023'},
#  {'title': 'Optimizing generative AI by backpropagating language model feedback',
#   'summary': 'Scientists have developed a groundbreaking framework called TextGrad, which optimizes generative AI systems by using feedback from large language models to automatically improve their performance. This innovation enables the creation of more effective AI systems across a wide range of tasks, from designing molecules with specific properties to optimizing radiotherapy treatment plans. By leveraging TextGrad, researchers can now easily develop powerful generative AI systems, accelerating progress in fields such as science, medicine, and engineering, without requiring extensive manual tweaking by domain experts.',
#   'url': 'https://www.semanticscholar.org/paper/Optimizing-generative-AI-by-backpropagating-model-Yuksekgonul-Bianchi/497d1aaa0f80b90b72e1a7519f1e4d1aefa2e429',
#   'year': '2025'},
#  {'title': 'GUIDANCE FOR GENERATIVE AI IN EDUCATION AND RESEARCH" FOR TEACHERS',
#   'summary': "In a groundbreaking move, UNESCO has introduced the world's first global guidelines on the use of Generative AI in education, providing a much-needed framework for countries to regulate and effectively utilize this technology. The guidelines come at a critical time, as the rapid emergence of publicly available Generative AI tools has outpaced national regulatory frameworks, leaving educational institutions vulnerable to concerns over user data privacy. By establishing clear guidelines, UNESCO aims to support countries in harnessing the potential of Generative AI to enhance education and research, while also ensuring the protection of users and promoting responsible AI use.",
#   'url': 'https://www.semanticscholar.org/paper/GUIDANCE-FOR-GENERATIVE-AI-IN-EDUCATION-AND-FOR-Boonlue/3b09a37c82d96afe0634c604664263bd50c141e0',
#   'year': '2024'}]
